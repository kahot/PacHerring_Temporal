# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv("~/programs/PacHerring/Output/LD/test.csv")

# %%
df
# Out:
#   pop_A pop_B
# 0   A/A   B/B
# 1   B/B     .
# 2   A/A   A/A

# %%
#read gt_df file
df= pd.read_csv("~/programs/PacHerring/Output/LD/gt_df.csv")

# %%
df.replace({'.': 'NA'},inplace =True)

# %%
df.head()
# Out:
#   Unnamed: 0 chr1_24227 chr1_24456 chr1_24457 chr1_24484 chr1_28680  \
# 0  0321_BC17         NA        A/A        A/A        A/A        C/C
# 1  0322_BC17        C/C         NA         NA         NA        A/A
# 2  0323_BC17         NA        A/A        A/A        A/A        A/A
# 3  0324_BC17        C/C        A/A        A/A        A/A        A/A
# 4  0325_BC17         NA        A/A        A/A        A/A         NA
#
#   chr1_29614 chr1_31248 chr1_33679 chr1_54914  ... chr26_12429085  \
# 0         NA        C/C         NA        C/C  ...            T/T
# 1         NA        C/C        C/C         NA  ...             NA
# 2        A/A        C/C        T/T         NA  ...            A/A
# 3         NA        C/C         NA         NA  ...            A/A
# 4        A/A        C/C         NA         NA  ...             NA
#
#   chr26_12434120 chr26_12437019 chr26_12437267 chr26_12438551 chr26_12438574  \
# 0             NA             NA             NA             NA             NA
# ...

# %%
df.to_csv("~/programs/PacHerring/Output/LD/gt_df_NAreplaced.csv")
